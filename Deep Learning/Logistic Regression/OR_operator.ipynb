# %% [markdown]
# # OR operator

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from math import exp, log

# %%
X = [(0,0), (1,0), (0,1), (1,1)]
Y = [0,1,1,1]
train_loss_list = []

# %%
class OR_operator():
    def __init__(self):
        self.w = np.random.random(size=2)
        self.b = np.random.random(size=1)
    
    def sigmoid(self, z):
        return 1/(1+exp(-z))
        
    def predict(self, x):
        z = np.inner(self.w, x)+self.b
        a = self.sigmoid(z)
        return a

# %%
model = OR_operator()

# %%
def train(X, Y, model, lr=0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    for x,y in zip(X, Y):
        a = model.predict(x)
        if y==1:
            cost-=log(a)
        else:
            cost-=log(1-a)
        
        dw0+=(a-y)*x[0]
        dw1+=(a-y)*x[1]
        db+=(a-y)
        
    cost/=m
    train_loss_list.append(cost)
    model.w[0]-=lr*dw0/m
    model.w[1]-=lr*dw1/m
    model.b-=lr*db/m
    
    return cost

# %%
for epoch in range(10000):
    cost = train(X, Y, model, 0.1)
    if epoch%100==0:
        print(epoch, cost)

plt.figure()
plt.title("train loss")
x1 = np.arange(0, len(train_loss_list))
plt.plot(x1, train_loss_list)
# Out:
# 0 0.4650035808409472
# 100 0.3421042787326408
# 200 0.2671295852509561
# 300 0.21747656117747372
# 400 0.18256332785240237
# 500 0.15679894938579217
# 600 0.13706697813549945
# 700 0.12151147567122735
# 800 0.10896129237074387
# 900 0.09864175204873643
# 1000 0.09002049723861494
# 1100 0.08272003511645143
# 1200 0.07646556917541039
# 1300 0.07105254416548248
# 1400 0.06632572827398563
# 1500 0.06216531922156427
# 1600 0.05847747313351095
# 1700 0.055187700503342325
# 1800 0.05223616851404799
# 1900 0.04957429955946982
# 2000 0.04716226878344633
# 2100 0.044967136362275804
# 2200 0.04296143520353591
# 2300 0.04112209020241406
# 2400 0.039429582121390035
# 2500 0.037867294173758156
# 2600 0.03642099661061139
# 2700 0.03507843663886836
# 2800 0.033829009513903344
# 2900 0.032663492755512655
# 3000 0.03157382986380967
# 3100 0.030552953157815064
# 3200 0.0295946377634627
# 3300 0.028693380574846532
# 3400 0.02784429936791897
# 3500 0.027043048276635978
# 3600 0.026285746631629695
# 3700 0.025568918771590145
# 3800 0.024889442911956026
# 3900 0.02424450752688594
# 4000 0.02363157399302167
# 4100 0.023048344475376924
# 4200 0.02249273422044173
# 4300 0.021962847569638302
# 4400 0.02145695712550525
# 4500 0.020973485599506493
# 4600 0.02051098994885378
# 4700 0.02006814747385747
# 4800 0.019643743599930482
# 4900 0.01923666111171459
# 5000 0.018845870642652342
# 5100 0.01847042225309563
# 5200 0.018109437954847183
# 5300 0.01776210506078367
# 5400 0.017427670255610504
# 5500 0.01710543429846173
# 5600 0.01679474728043113
# 5700 0.016495004370610206
# 5800 0.016205641993112575
# 5900 0.015926134385157855
# 6000 0.015655990492770052
# 6100 0.015394751166200048
# 6200 0.015141986621952335
# 6300 0.014897294142401443
# 6400 0.014660295987529083
# 6500 0.014430637496375225
# 6600 0.014207985358457078
# 6700 0.01399202603771646
# 6800 0.013782464333566658
# 6900 0.013579022065364514
# 7000 0.013381436868164622
# 7100 0.013189461088958203
# 7200 0.013002860773774435
# 7300 0.012821414737061118
# 7400 0.012644913705671071
# 7500 0.012473159530587844
# 7600 0.012305964460234606
# 7700 0.012143150469840082
# 7800 0.011984548641893012
# 7900 0.011829998593214888
# 8000 0.011679347944616746
# 8100 0.011532451829504237
# 8200 0.011389172438140848
# 8300 0.011249378594595192
# 8400 0.011112945363674584
# 8500 0.010979753685403264
# 8600 0.010849690034820487
# 8700 0.010722646105084941
# 8800 0.010598518512043508
# 8900 0.010477208518594926
# 9000 0.010358621777319136
# 9100 0.010242668089979281
# 9200 0.010129261182623153
# 9300 0.010018318495118755
# 9400 0.009909760984056054
# 9500 0.009803512938038399
# 9600 0.00969950180446549
# 9700 0.009597658026984316
# 9800 0.009497914892850857
# 9900 0.009400208389506353

# %%
for epoch in range(10000):
    cost = train(X, Y, model, 0.01)
    if epoch%100==0:
        print(epoch, cost)

plt.figure()
plt.title("train loss")
x1 = np.arange(0, len(train_loss_list))
plt.plot(x1, train_loss_list)
# Out:
# 0 0.009304477069726739
# 100 0.009295010710535128
# 200 0.009285563451313358
# 300 0.009276135234598653
# 400 0.009266726003157444
# 500 0.009257335699984978
# 600 0.009247964268303105
# 700 0.009238611651559854
# 800 0.009229277793428291
# 900 0.009219962637805312
# 1000 0.009210666128810026
# 1100 0.009201388210783718
# 1200 0.009192128828287759
# 1300 0.009182887926103124
# 1400 0.009173665449228955
# 1500 0.009164461342881758
# 1600 0.009155275552494103
# 1700 0.009146108023713757
# 1800 0.009136958702402592
# 1900 0.009127827534635249
# 2000 0.009118714466698607
# 2100 0.009109619445090273
# 2200 0.00910054241651795
# 2300 0.009091483327897977
# 2400 0.009082442126354586
# 2500 0.009073418759219198
# 2600 0.009064413174028365
# 2700 0.009055425318524246
# 2800 0.009046455140652268
# 2900 0.009037502588560871
# 3000 0.009028567610600372
# 3100 0.009019650155322046
# 3200 0.009010750171476933
# 3300 0.009001867608015081
# 3400 0.00899300241408442
# 3500 0.008984154539030125
# 3600 0.008975323932393075
# 3700 0.008966510543909808
# 3800 0.00895771432351041
# 3900 0.00894893522131879
# 4000 0.008940173187650767
# 4100 0.00893142817301378
# 4200 0.008922700128105712
# 4300 0.00891398900381402
# 4400 0.008905294751214802
# 4500 0.008896617321571734
# 4600 0.008887956666335751
# 4700 0.008879312737143402
# 4800 0.008870685485816474
# 4900 0.008862074864360926
# 5000 0.008853480824965995
# 5100 0.00884490332000354
# 5200 0.008836342302026711
# 5300 0.008827797723769595
# 5400 0.008819269538146183
# 5500 0.008810757698249396
# 5600 0.008802262157350145
# 5700 0.008793782868896928
# 5800 0.008785319786514631
# 5900 0.00877687286400368
# 6000 0.008768442055339573
# 6100 0.008760027314671499
# 6200 0.008751628596322232
# 6300 0.008743245854786419
# 6400 0.008734879044730701
# 6500 0.008726528120992233
# 6600 0.008718193038577989
# 6700 0.008709873752664481
# 6800 0.008701570218596135
# 6900 0.008693282391885318
# 7000 0.008685010228211111
# 7100 0.008676753683418552
# 7200 0.008668512713517798
# 7300 0.008660287274683567
# 7400 0.00865207732325432
# 7500 0.008643882815731444
# 7600 0.008635703708778473
# 7700 0.008627539959220406
# 7800 0.008619391524042917
# 7900 0.00861125836039153
# 8000 0.008603140425571129
# 8100 0.008595037677044804
# 8200 0.00858695007243369
# 8300 0.008578877569515628
# 8400 0.008570820126225
# 8500 0.008562777700651492
# 8600 0.008554750251039703
# 8700 0.008546737735788347
# 8800 0.008538740113449841
# 8900 0.008530757342728798
# 9000 0.008522789382482125
# 9100 0.00851483619171814
# 9200 0.008506897729595606
# 9300 0.008498973955423225
# 9400 0.008491064828659037
# 9500 0.008483170308909653
# 9600 0.008475290355929364
# 9700 0.008467424929619967
# 9800 0.008459573990029612
# 9900 0.008451737497352257

# %%
for epoch in range(10000):
    cost = train(X, Y, model, 0.001)
    if epoch%100==0:
        print(epoch, cost)

plt.figure()
plt.title("train loss")
x1 = np.arange(0, len(train_loss_list))
plt.plot(x1, train_loss_list)
# Out:
# 0 0.008443915411927273
# 100 0.008443133997493
# 200 0.00844235272669505
# 300 0.008441571599493982
# 400 0.008440790615850522
# 500 0.008440009775725087
# 600 0.008439229079078408
# 700 0.008438448525871011
# 800 0.008437668116063682
# 900 0.00843688784961701
# 1000 0.008436107726491749
# 1100 0.008435327746648406
# 1200 0.008434547910047987
# 1300 0.008433768216650947
# 1400 0.008432988666418091
# 1500 0.008432209259310215
# 1600 0.008431429995288127
# 1700 0.008430650874312447
# 1800 0.00842987189634416
# 1900 0.008429093061343942
# 2000 0.008428314369272608
# 2100 0.008427535820091115
# 2200 0.00842675741376022
# 2300 0.008425979150240773
# 2400 0.008425201029493703
# 2500 0.008424423051479881
# 2600 0.008423645216160156
# 2700 0.008422867523495596
# 2800 0.008422089973446912
# 2900 0.008421312565975368
# 3000 0.008420535301041617
# 3100 0.008419758178606815
# 3200 0.00841898119863189
# 3300 0.008418204361077921
# 3400 0.00841742766590587
# 3500 0.00841665111307678
# 3600 0.008415874702551694
# 3700 0.00841509843429169
# 3800 0.008414322308257813
# 3900 0.008413546324411197
# 4000 0.008412770482712996
# 4100 0.00841199478312415
# 4200 0.008411219225605959
# 4300 0.008410443810119442
# 4400 0.008409668536625928
# 4500 0.008408893405086437
# 4600 0.008408118415462303
# 4700 0.008407343567714571
# 4800 0.008406568861804601
# 4900 0.008405794297693642
# 5000 0.008405019875342742
# 5100 0.008404245594713318
# 5200 0.008403471455766672
# 5300 0.008402697458463915
# 5400 0.008401923602766571
# 5500 0.008401149888635811
# 5600 0.008400376316032993
# 5700 0.008399602884919505
# 5800 0.008398829595256653
# 5900 0.008398056447005886
# 6000 0.00839728344012851
# 6100 0.008396510574585998
# 6200 0.008395737850339577
# 6300 0.008394965267351026
# 6400 0.008394192825581516
# 6500 0.00839342052499258
# 6600 0.008392648365545721
# 6700 0.008391876347202306
# 6800 0.008391104469924008
# 6900 0.008390332733672136
# 7000 0.008389561138408393
# 7100 0.008388789684094284
# 7200 0.008388018370691344
# 7300 0.008387247198161111
# 7400 0.008386476166465179
# 7500 0.008385705275565189
# 7600 0.008384934525422737
# 7700 0.008384163915999361
# 7800 0.008383393447256792
# 7900 0.008382623119156708
# 8000 0.008381852931660617
# 8100 0.008381082884730454
# 8200 0.008380312978327783
# 8300 0.008379543212414142
# 8400 0.00837877358695146
# 8500 0.008378004101901535
# 8600 0.008377234757225875
# 8700 0.008376465552886413
# 8800 0.008375696488844942
# 8900 0.008374927565063115
# 9000 0.008374158781502808
# 9100 0.008373390138125927
# 9200 0.00837262163489421
# 9300 0.008371853271769486
# 9400 0.008371085048713651
# 9500 0.00837031696568859
# 9600 0.008369549022656183
# 9700 0.008368781219578254
# 9800 0.008368013556416904
# 9900 0.008367246033133904
